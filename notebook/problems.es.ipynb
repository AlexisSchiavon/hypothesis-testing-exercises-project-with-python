# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
# TODO
import numpy as np
from scipy.stats import ttest_ind

"""
Hipótesis Nula: No existe diferencia en la pérdida de peso promedio entre las personas que siguieron la Dieta 1 y las que siguieron la Dieta 2.

Hipótesis Alternativa: Existe una diferencia en la pérdida de peso promedio entre las personas que siguieron la Dieta 1 y las que siguieron la Dieta 2.
"""
a = 0.05

dieta1 = [2.0, 2.5, 3.0, 2.8, 2.3, 2.7, 2.5]
dieta2 = [3.0, 3.2, 3.1, 2.9, 2.8, 3.0, 3.2]

media_dieta_1 = np.mean(dieta1)
media_dieta_2 = np.mean(dieta2)
desviacion_dieta_1 = np.std(dieta1)
desviacion_dieta_2 = np.std(dieta2)

estadisticas_t, valor_p = ttest_ind(dieta1, dieta2, equal_var=False)

print(f"Media Dieta 1: {media_dieta_1}")
print(f"Desviación Estándar Dieta 1: {desviacion_dieta_1}")
print(f"Media Dieta 2: {media_dieta_2:}")
print(f"Desviación Estándar Dieta 2: {desviacion_dieta_2}")
print(f"Estadísticas t: {estadisticas_t}")
print(f"Valor p: {estadisticas_t}")

if valor_p <= a:
    print(f"\nComo p {valor_p} es <= alfa {a}, la hipotesis nula no es aceptada.")
    print("Existe una diferencia entre las medias de las dos dietas.")
else:
    print(f"\nComo p {valor_p} > alfa {a}, no se rechaza H0.")
    print("No hay suficientes datos para afirmar una diferencia entre las medias de las dos dietas.")
# Out:
# Media Dieta 1: 2.542857142857143
# Desviación Estándar Dieta 1: 0.306394436993246
# Media Dieta 2: 3.0285714285714285
# Desviación Estándar Dieta 2: 0.13850513878332382
# Estadísticas t: -3.5383407969933938
# Valor p: -3.5383407969933938
#
# Como p 0.007125697852423989 es <= alfa 0.05, la hipotesis nula no es aceptada.
# Existe una diferencia entre las medias de las dos dietas.

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# TODO
from scipy.stats import f_oneway
from statsmodels.stats.multicomp import pairwise_tukeyhsd

"""
Hipótesis Nula: Los tres fertilizantes producen en promedio la misma cantidad de maíz.

Hipótesis Alternativa: No todos los fertilizantes producen el mismo rendimiento promedio.
"""
a = 0.05

fertilizante1 = [20, 21, 20, 19, 20]
fertilizante2 = [22, 21, 23, 22, 21]
fertilizante3 = [24, 23, 22, 23, 24]

media_fertilizante_1 = np.mean(fertilizante1)
media_fertilizante_2 = np.mean(fertilizante2)
media_fertilizante_3 = np.mean(fertilizante3)

varianza_fertilizante_1 = np.var(fertilizante1)
varianza_fertilizante_2 = np.var(fertilizante2)
varianza_fertilizante_3 = np.var(fertilizante3)

estadisticas_f, valor_p_anova = f_oneway(fertilizante1, fertilizante2, fertilizante3)

print(f"Media Fertilizante 1: {media_fertilizante_1}")
print(f"Varianza Fertilizante 1: {varianza_fertilizante_1}")
print(f"Media Fertilizante 2: {media_fertilizante_2}")
print(f"Varianza Fertilizante 2: {varianza_fertilizante_2}")
print(f"Media Fertilizante 3: {media_fertilizante_3}")
print(f"Varianza Fertilizante 3: {varianza_fertilizante_3}")
print(f"\nResultados ANOVA:")
print(f"Estadisticas F: {estadisticas_f}")
print(f"Valor p: {valor_p_anova}")

if valor_p_anova <= a:
    print(f"Como p {valor_p_anova} <= alfa {a}, no se acepta la hipotesis nula.")
    print("Hay una diferencia en el rendimiento promedio de al menos uno de los fertilizantes.")

    print("\nPrueba Tukey HSD:")
    all_data = np.concatenate([fertilizante1, fertilizante2, fertilizante3])
    group_labels = ['F1'] * len(fertilizante1) + ['F2'] * len(fertilizante2) + ['F3'] * len(fertilizante3)

    resultados_tukey = pairwise_tukeyhsd(endog=all_data, groups=group_labels, alpha=a)
    print(resultados_tukey)

else:
    print(f"Como p {valor_p_anova} > alfa {a}, se acepta la hipotesis nula.")
# Out:
# Media Fertilizante 1: 20.0
# Varianza Fertilizante 1: 0.4
# Media Fertilizante 2: 21.8
# Varianza Fertilizante 2: 0.5599999999999999
# Media Fertilizante 3: 23.2
# Varianza Fertilizante 3: 0.5599999999999999
#
# Resultados ANOVA:
# Estadisticas F: 20.315789473684188
# Valor p: 0.00014047824793190472
# Como p 0.00014047824793190472 <= alfa 0.05, no se acepta la hipotesis nula.
# Hay una diferencia en el rendimiento promedio de al menos uno de los fertilizantes.
#
# Prueba Tukey HSD:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#     F1     F2      1.8 0.0099 0.4572 3.1428   True
#     F1     F3      3.2 0.0001 1.8572 4.5428   True
#     F2     F3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------
